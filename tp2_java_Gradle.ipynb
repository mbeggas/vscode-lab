# %%
# تثبيت Java
# !apt-get install -y openjdk-17-jdk

# إعداد متغيرات البيئة
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-17-openjdk-amd64"
os.environ["PATH"] += ":/usr/lib/jvm/java-17-openjdk-amd64/bin"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libxt-dev libxtst6 libxxf86dga1
#   openjdk-17-jdk-headless openjdk-17-jre openjdk-17-jre-headless x11-utils
# Suggested packages:
#   libxt-doc openjdk-17-demo openjdk-17-source visualvm libnss-mdns
#   fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   | fonts-wqy-zenhei fonts-indic mesa-utils
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libxt-dev libxtst6 libxxf86dga1 openjdk-17-jdk
#   openjdk-17-jdk-headless openjdk-17-jre openjdk-17-jre-headless x11-utils
# 0 upgraded, 12 newly installed, 0 to remove and 34 not upgraded.
# Need to get 125 MB of archives.
# After this operation, 287 MB of additional disk space will be used.
# ...

# %%
# تحميل وتثبيت Gradle
# !wget https://services.gradle.org/distributions/gradle-8.7-bin.zip
# !unzip gradle-8.7-bin.zip -d /usr/local/
os.environ["PATH"] += ":/usr/local/gradle-8.7/bin"
# Out:
# --2025-04-30 22:37:43--  https://services.gradle.org/distributions/gradle-8.7-bin.zip
# Resolving services.gradle.org (services.gradle.org)... 104.16.72.101, 104.16.73.101, 2606:4700::6810:4865, ...
# Connecting to services.gradle.org (services.gradle.org)|104.16.72.101|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/gradle/gradle-distributions/releases/download/v8.7.0/gradle-8.7-bin.zip [following]
# --2025-04-30 22:37:43--  https://github.com/gradle/gradle-distributions/releases/download/v8.7.0/gradle-8.7-bin.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !gradle init --type java-application --dsl groovy --project-name my-gradle-app --package com.example --test-framework junit-jupiter --incubating --no-interactive
# Out:
# > Connecting to Daemon<-------------> 0% INITIALIZING s]> Evaluating settings
# FAILURE: Build failed with an exception.
#
# * What went wrong:
# Problem configuring task :init from command line.
# > Unknown command-line option '--no-interactive'.
#
# * Try:
# > Run gradle help --task :init to get task usage details.
# > Run with --stacktrace option to get the stack trace.
# > Run with --info or --debug option to get more log output.
# > Run with --scan to get full insights.
# > Get more help at https://help.gradle.org.
#
# BUILD FAILED in 1s
#
#
# <-------------> 0% WAITING> IDLE

# %%
import os
os.makedirs("my-gradle-app/src/main/java/com/exaple", exist_ok=True)

# %%
# %%writefile my-gradle-app/src/main/java/com/example/Calculator.java
# import org.apache.commons.lang3.StringUtils;
#
# public class Calculator {
#     public int add(int a, int b) {
#         return a + b;
#     }
#
#     public int multiply(int a, int b) {
#         return a * b;
#     }
#
#     public int subtract(int a, int b) {
#         return a - b;
#     }
#
#     public int divide(int a, int b) {
#         if (b == 0) {
#             throw new ArithmeticException("Division by zero");
#         }
#         return a / b;
#     }
#
#     public String reverse(String input) {
#         return StringUtils.reverse(input);
#     }
# }
# Out:
# Writing my-gradle-app/src/main/java/com/example/Calculator.java

# %%
# %%writefile my-gradle-app/src/main/java/com/example/App.java
# package com.example;
#
# public class App {
#     public static void main(String[] args) {
#         Calculator calculator = new Calculator();
#
#         int sum = calculator.add(10, 5);
#         int product = calculator.multiply(10, 5);
#         int difference = calculator.subtract(10, 5);
#         int quotient = calculator.divide(10, 5);
#         String reversed = calculator.reverse("hello");
#
#         System.out.println("Sum: " + sum);
#         System.out.println("Product: " + product);
#         System.out.println("Difference: " + difference);
#         System.out.println("Quotient: " + quotient);
#         System.out.println("Reversed: " + reversed);
#     }
# }
# Out:
# Writing my-gradle-app/src/main/java/com/example/App.java

# %%
# %%writefile my-gradle-app/build.gradle
# plugins {
#     id 'application'
# }
#
# repositories {
#     mavenCentral()
# }
#
# dependencies {
#     implementation 'org.apache.commons:commons-lang3:3.12.0'
#     testImplementation 'org.junit.jupiter:junit-jupiter:5.7.1'
# }
#
# application {
#     mainClass = 'com.example.App'
# }
#
# test {
#     useJUnitPlatform()
# }
# Out:
# Writing my-gradle-app/build.gradle

# %%
import os
os.makedirs("my-gradle-app/src/test/java/com/example", exist_ok=True)

# %%
# %%writefile my-gradle-app/src/test/java/com/example/CalculatorTest.java
# package com.example;
#
# import org.junit.jupiter.api.Test;
# import static org.junit.jupiter.api.Assertions.*;
#
# public class CalculatorTest {
#     Calculator calculator = new Calculator();
#
#     @Test
#     public void testAddition() {
#         assertEquals(15, calculator.add(10, 5));
#         assertEquals(0, calculator.add(-5, 5));
#     }
#
#     @Test
#     public void testMultiplication() {
#         assertEquals(50, calculator.multiply(10, 5));
#         assertEquals(0, calculator.multiply(0, 5));
#     }
#
#     @Test
#     public void testSubtraction() {
#         assertEquals(5, calculator.subtract(10, 5));
#         assertEquals(-10, calculator.subtract(-5, 5));
#     }
#
#     @Test
#     public void testDivision() {
#         assertEquals(2, calculator.divide(10, 5));
#         assertThrows(ArithmeticException.class, () -> calculator.divide(5, 0));
#     }
#
#     @Test
#     public void testReverse() {
#         assertEquals("cba", calculator.reverse("abc"));
#         assertEquals("54321", calculator.reverse("12345"));
#     }
# }
# Out:
# Writing my-gradle-app/src/test/java/com/example/CalculatorTest.java

# %%
# !cd my-gradle-app && gradle build
# !cd my-gradle-app && gradle run
# Out:
# > Connecting to Daemon<-------------> 0% INITIALIZING s]> IDLE<-------------> 0% CONFIGURING s]> root project<-------------> 0% CONFIGURING s]<-------------> 0% CONFIGURING s]<-------------> 0% CONFIGURING s]<-------------> 0% CONFIGURING s]<-------------> 0% CONFIGURING s]<-------------> 0% CONFIGURING s]<-------------> 0% CONFIGURING s]<-------------> 0% CONFIGURING s]<-------------> 0% CONFIGURING [1s]<=============> 100% CONFIGURING [1s]> IDLE<=============> 100% CONFIGURING [2s]<-------------> 0% EXECUTING [2s]> :compileJava> :compileJava > Resolve dependencies of :compileClasspath> :compileJava > Resolve dependencies of :compileClasspath > commons-lang3-3.12<-------------> 0% EXECUTING [3s]<-------------> 0% EXECUTING [4s]<-------------> 0% EXECUTING [5s]> :compileJava > Resolve dependencies of :compileClasspath> :compileJava > Resolve dependencies of :compileClasspath > commons-parent-52.> :compileJava > Resolve dependencies of :compileClasspath> :compileJava > Resolve files o
# ...

# %%
# !cd my-gradle-app && gradle test
# Out:
# <-------------> 0% CONFIGURING s]> root project<=============> 100% CONFIGURING s]> IDLE<-------------> 0% EXECUTING s]> :compileJava<-------------> 0% EXECUTING s]
# > Task :compileJava FAILED
# /content/my-gradle-app/src/main/java/com/example/App.java:5: error: cannot find symbol
#         Calculator calculator = new Calculator();
#         ^
#   symbol:   class Calculator
#   location: class App
# /content/my-gradle-app/src/main/java/com/example/App.java:5: error: cannot find symbol
#         Calculator calculator = new Calculator();
#                                     ^
#   symbol:   class Calculator
#   location: class App
# 2 errors
#
# FAILURE: Build failed with an exception.
#
# * What went wrong:
# Execution failed for task ':compileJava'.
# > Compilation failed; see the compiler error output for details.
#
# * Try:
# > Run with --info option to get more log output.
# > Run with --scan to get full insights.
#
# BUILD FAILED in 1s
# 1 actionable task: 1 executed
#
#
# ...

# %%
# !cd my-gradle-app && gradle test --tests com.example.CalculatorTest.testReverse
# Out:
# <-------------> 0% INITIALIZING s]<=============> 100% CONFIGURING s]
# <-------------> 0% EXECUTING s]> :compileJava > Resolve dependencies of :compileClasspath<-------------> 0% EXECUTING s]> :compileJava
# > Task :compileJava FAILED
# /content/my-gradle-app/src/main/java/com/example/App.java:5: error: cannot find symbol
#         Calculator calculator = new Calculator();
#         ^
#   symbol:   class Calculator
#   location: class App
# /content/my-gradle-app/src/main/java/com/example/App.java:5: error: cannot find symbol
#         Calculator calculator = new Calculator();
#                                     ^
#   symbol:   class Calculator
#   location: class App
# 2 errors
#
# FAILURE: Build failed with an exception.
#
# * What went wrong:
# Execution failed for task ':compileJava'.
# > Compilation failed; see the compiler error output for details.
#
# * Try:
# > Run with --info option to get more log output.
# > Run with --scan to get full insights.
#
# BUILD FAILED in 1s
# ...
